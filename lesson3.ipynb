# %%
import pandas as pd

# %%
jmena = pd.read_csv('jmena.csv')
studenti1 = pd.read_csv('studenti1.csv')
studenti2 = pd.read_csv('studenti2.csv')
studenti2
# Out:
#        jméno      příjmení                      obor  ročník  kruh  prospěch
# 0       Petr       Vanžura         správa IT systémů     3.0   3.0      2.24
# 1      Josef         Pícha        webové inženýrství     2.0   9.0      2.52
# 2     Michal       Steiner  informatika a management     2.0   2.0      2.33
# 3     Renata     Václavová  informatika a management     2.0   3.0      2.83
# 4    Jarmila       Selucká  informatika a management     NaN   6.0      2.34
# ..       ...           ...                       ...     ...   ...       ...
# 135   Daniel  Brandstätter  informatika a management     4.0   2.0      2.05
# 136    Lukáš          Čech  informatika a management     5.0   NaN      1.59
# 137   Dagmar      Košanová    teoretická informatika     5.0  10.0      1.34
# 138    Ivana    Macháčková        webové inženýrství     1.0   NaN      2.92
# 139  Martina       Turková    softwarové inženýrství     5.0   8.0      1.54
#
# [140 rows x 6 columns]

# %%
pd.concat([jmena, studenti1, studenti2])
# Out:
#        jméno   četnost   věk pohlaví        svátek      původ      příjmení
# 0       Jiří  296090.0  49.0       m          24.4      řecký           NaN  \
# 1        Jan  293938.0  40.0       m   24.6. a 6.7  hebrejský           NaN
# 2       Petr  272135.0  42.0       m  22.2. a 29.6      řecký           NaN
# 3       Jana  264944.0  50.0       ž          24.5  hebrejský           NaN
# 4      Marie  260526.0  65.0       ž          12.9  hebrejský           NaN
# ..       ...       ...   ...     ...           ...        ...           ...
# 135   Daniel       NaN   NaN     NaN           NaN        NaN  Brandstätter
# 136    Lukáš       NaN   NaN     NaN           NaN        NaN          Čech
# 137   Dagmar       NaN   NaN     NaN           NaN        NaN      Košanová
# 138    Ivana       NaN   NaN     NaN           NaN        NaN    Macháčková
# 139  Martina       NaN   NaN     NaN           NaN        NaN       Turková
#
#                          obor  ročník  kruh  prospěch
# ...

# %%
maturita = pd.concat([jmena, studenti1, studenti2], ignore_index=True)
maturita_nova = maturita.dropna(subset=["ročník"])
maturita_nova
# Out:
#        jméno  četnost  věk pohlaví svátek původ      příjmení
# 100  Ludmila      NaN  NaN     NaN    NaN   NaN    Šindlerová  \
# 101      Jan      NaN  NaN     NaN    NaN   NaN       Pekárek
# 102    Milan      NaN  NaN     NaN    NaN   NaN         Weiss
# 103   Jiřina      NaN  NaN     NaN    NaN   NaN       Petrová
# 104    Josef      NaN  NaN     NaN    NaN   NaN      Navrátil
# ..       ...      ...  ...     ...    ...   ...           ...
# 440   Daniel      NaN  NaN     NaN    NaN   NaN  Brandstätter
# 441    Lukáš      NaN  NaN     NaN    NaN   NaN          Čech
# 442   Dagmar      NaN  NaN     NaN    NaN   NaN      Košanová
# 443    Ivana      NaN  NaN     NaN    NaN   NaN    Macháčková
# 444  Martina      NaN  NaN     NaN    NaN   NaN       Turková
#
#                          obor  ročník  kruh  prospěch
# 100  informatika a management     4.0  11.0      2.49
# 101    softwarové inženýrství     1.0   7.0      1.05
# 102        počítačová grafika     5.0  11.0      2.62
# ...

# %%
studenti_prez = studenti_prez
