# %% [markdown]
#  # `pandas`: Základní dotazy
# Odkaz na lekci: https://kodim.cz/kurzy/python-data-1/python-pro-data-1/podmineny-vyber/podmineny-vyber

# %%
import pandas

# %% [markdown]
# Data si stáhni [zde](https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/nacteni-dat/staty.json). Jsou ve formátu JSON, proto použijeme vhodnou metodu `read_json`:

# %%
staty = pandas.read_json('staty.json')
staty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        250 non-null    object
#  1   alpha2Code  250 non-null    object
#  2   alpha3Code  250 non-null    object
#  3   capital     250 non-null    object
#  4   region      250 non-null    object
#  5   subregion   250 non-null    object
#  6   population  250 non-null    int64
#  7   area        240 non-null    float64
#  8   gini        153 non-null    float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 17.7+ KB

# %% [markdown]
# Ukážeme si, jak filtrovat řádky v tabulce na základě hodnot ve sloupcích. Například, které státy mají počet obyvatel menší než 1000?

# %%
#print(staty["population"] < 10_000)
staty["population"] < 10_000
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 245     True
# 246    False
# 247    False
# 248    False
# 249    False
# Name: population, Length: 250, dtype: bool

# %%
staty[staty["population"] < 10_000]
# Out:
#                                              name alpha2Code alpha3Code
# 8                                      Antarctica         AQ        ATA  \
# 30                                  Bouvet Island         BV        BVT
# 32                 British Indian Ocean Territory         IO        IOT
# 33           United States Minor Outlying Islands         UM        UMI
# 49                               Christmas Island         CX        CXR
# 50                        Cocos (Keeling) Islands         CC        CCK
# 73                    Falkland Islands (Malvinas)         FK        FLK
# 80                    French Southern Territories         TF        ATF
# 98              Heard Island and McDonald Islands         HM        HMD
# 99                                       Holy See         VA        VAT
# 150                                    Montserrat         MS        MSR
# 163                                          Niue         NU        NIU
# 164                                Norfolk Island         NF        NFK
# 177                                      Pitcairn         PN        PCN
# 187                              Saint Barthélemy         BL        BLM
# 188  Saint Helena, Ascension and Tristan da Cunha         SH        SHN
# 192                     Saint Pierre and Miquelon         PM        SPM
# 209  South Georgia and the South Sandwich Islands         GS        SGS
# 216                        Svalbard and Jan Mayen         SJ        SJM
# 227                                       Tokelau         TK        TKL
#
#                capital    region                  subregion  population
# 8                          Polar                                   1000  \
# 30                                                                    0
# 32        Diego Garcia    Africa             Eastern Africa        3000
# 33                      Americas           Northern America         300
# 49    Flying Fish Cove   Oceania  Australia and New Zealand        2072
# 50         West Island   Oceania  Australia and New Zealand         550
# 73             Stanley  Americas              South America        2563
# 80   Port-aux-Français    Africa            Southern Africa         140
# 98                                                                    0
# 99                Rome    Europe            Southern Europe         451
# 150           Plymouth  Americas                  Caribbean        4922
# 163              Alofi   Oceania                  Polynesia        1470
# 164           Kingston   Oceania  Australia and New Zealand        2302
# 177          Adamstown   Oceania                  Polynesia          56
# 187           Gustavia  Americas                  Caribbean        9417
# 188          Jamestown    Africa             Western Africa        4255
# 192       Saint-Pierre  Americas           Northern America        6069
# 209  King Edward Point  Americas              South America          30
# 216       Longyearbyen    Europe            Northern Europe        2562
# 227            Fakaofo   Oceania                  Polynesia        1411
#
#             area  gini
# 8    14000000.00   NaN
# 30         49.00   NaN
# 32         60.00   NaN
# 33           NaN   NaN
# 49        135.00   NaN
# 50         14.00   NaN
# 73      12173.00   NaN
# 80       7747.00   NaN
# 98        412.00   NaN
# 99          0.44   NaN
# 150       102.00   NaN
# 163       260.00   NaN
# 164        36.00   NaN
# 177        47.00   NaN
# 187        21.00   NaN
# 188          NaN   NaN
# 192       242.00   NaN
# 209          NaN   NaN
# 216          NaN   NaN
# 227        12.00   NaN

# %% [markdown]
# Které státy leží v subregionu `"South America"`?

# %%
staty[staty["subregion"] == "South America"]
# Out:
#                                              name alpha2Code alpha3Code
# 10                                      Argentina         AR        ARG  \
# 26               Bolivia (Plurinational State of)         BO        BOL
# 31                                         Brazil         BR        BRA
# 47                                          Chile         CL        CHL
# 51                                       Colombia         CO        COL
# 66                                        Ecuador         EC        ECU
# 73                    Falkland Islands (Malvinas)         FK        FLK
# 78                                  French Guiana         GF        GUF
# 96                                         Guyana         GY        GUY
# 174                                      Paraguay         PY        PRY
# 175                                          Peru         PE        PER
# 209  South Georgia and the South Sandwich Islands         GS        SGS
# 215                                      Suriname         SR        SUR
# 240                                       Uruguay         UY        URY
# 243            Venezuela (Bolivarian Republic of)         VE        VEN
#
#                capital    region      subregion  population       area  gini
# 10        Buenos Aires  Americas  South America    43590400  2780400.0  44.5
# 26               Sucre  Americas  South America    10985059  1098581.0  56.3
# 31            Brasília  Americas  South America   206135893  8515767.0  54.7
# 47            Santiago  Americas  South America    18191900   756102.0  52.1
# 51              Bogotá  Americas  South America    48759958  1141748.0  55.9
# 66               Quito  Americas  South America    16545799   276841.0  49.3
# 73             Stanley  Americas  South America        2563    12173.0   NaN
# 78             Cayenne  Americas  South America      254541        NaN   NaN
# 96          Georgetown  Americas  South America      746900   214969.0  44.5
# 174           Asunción  Americas  South America     6854536   406752.0  52.4
# 175               Lima  Americas  South America    31488700  1285216.0  48.1
# 209  King Edward Point  Americas  South America          30        NaN   NaN
# 215         Paramaribo  Americas  South America      541638   163820.0  52.9
# 240         Montevideo  Americas  South America     3480222   181034.0  39.7
# 243            Caracas  Americas  South America    31028700   916445.0  44.8

# %% [markdown]
# Které státy mají nízký index ekonomické nerovnosti, např. menší než 30?

# %%
staty[staty["gini"] < 30].reset_index(drop=True)
# Out:
#               name alpha2Code alpha3Code      capital  region
# 0      Afghanistan         AF        AFG        Kabul    Asia  \
# 1          Austria         AT        AUT       Vienna  Europe
# 2          Belarus         BY        BLR        Minsk  Europe
# 3         Bulgaria         BG        BGR        Sofia  Europe
# 4   Czech Republic         CZ        CZE       Prague  Europe
# 5          Denmark         DK        DNK   Copenhagen  Europe
# 6         Ethiopia         ET        ETH  Addis Ababa  Africa
# 7          Finland         FI        FIN     Helsinki  Europe
# 8          Germany         DE        DEU       Berlin  Europe
# 9       Kazakhstan         KZ        KAZ       Astana    Asia
# 10          Norway         NO        NOR         Oslo  Europe
# 11          Serbia         RS        SRB     Belgrade  Europe
# 12        Slovakia         SK        SVK   Bratislava  Europe
# 13          Sweden         SE        SWE    Stockholm  Europe
# 14         Ukraine         UA        UKR         Kiev  Europe
#
#           subregion  population       area  gini
# 0     Southern Asia    27657145   652230.0  27.8
# 1    Western Europe     8725931    83871.0  26.0
# 2    Eastern Europe     9498700   207600.0  26.5
# 3    Eastern Europe     7153784   110879.0  28.2
# 4    Eastern Europe    10558524    78865.0  26.0
# 5   Northern Europe     5717014    43094.0  24.0
# 6    Eastern Africa    92206005  1104300.0  29.8
# 7   Northern Europe     5491817   338424.0  26.9
# 8    Western Europe    81770900   357114.0  28.3
# 9      Central Asia    17753200  2724900.0  29.0
# 10  Northern Europe     5223256   323802.0  25.8
# 11  Southern Europe     7076372    88361.0  27.8
# 12   Eastern Europe     5426252    49037.0  26.0
# 13  Northern Europe     9894888   450295.0  25.0
# 14   Eastern Europe    42692393   603700.0  26.4

# %% [markdown]
# ## Kombinace podmínek
# Které státy jsou velké rozlohou (např. víc než 100 000), a mají zároveň malý počet obyvatel (méně než 1 milion)?

# %%
staty[(staty["population"])]

# %% [markdown]
# Které státy leží v Evropě nebo v Africe?

# %% [markdown]
# ## Metoda `isin`
# Které státy leží v Evropě nebo v Africe?

# %% [markdown]
# ## Metoda `between`
# Které státy mají počet obyvatel mezi jedním a pěti miliony?

# %% [markdown]
# ## Cvičení
# Odkaz na cvičení: https://kodim.cz/kurzy/python-data-1/python-pro-data-1/podmineny-vyber/podmineny-vyber#excs%3Eceska-jmena-2
